# %% [markdown]
# <a href="https://colab.research.google.com/github/gsgauravsinha/my-dash/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Hypothetical dataset
data = {
    'Review': [
        "The app is slow and crashes frequently.",
        "Great app, but needs more features.",
        "Terrible user interface, difficult to navigate.",
        "Love the design, but it lacks important functions.",
        "Constantly freezes on my device.",
        "Excellent features, but the ads are annoying.",
        "Navigation is smooth, but the content is outdated.",
        "Crashed during an important task, very frustrating.",
        "Intuitive interface, but the performance is poor.",
        "Ads pop up too often, disrupts the learning experience.",
        "Impressive functionality, but it drains my battery quickly.",
        "Difficult to find specific topics in the app.",
        "Smooth experience overall, but the login process is cumbersome.",
        "Too many bugs, needs a major update.",
        "The app is not user-friendly at all.",
        "Informative content, but the UI is outdated.",
        "I love the app, but it needs better customer support.",
        "The app frequently logs me out unexpectedly.",
        "Needs more interactive elements for engaging learning.",
        "Error messages are not clear, hard to troubleshoot issues.",
        "The hotel app's search functionality is a mess. It never finds the hotels I'm actually looking for.",
    "Flight booking app is a nightmare. It charged me twice for the same ticket, and getting a refund is a headache.",
    "Hotel reservation process is overly complicated. It took me ages to figure out how to confirm my booking.",
    "Flight app constantly bombards me with irrelevant notifications. Annoying and disruptive.",
    "This hotel booking app needs a total overhaul. The user interface is outdated and confusing.",
    "Flight reservations disappear randomly from the app. I had to rebook multiple times due to this glitch.",
    "Hotel prices fluctuate like crazy. One moment it's affordable, the next it's ridiculously expensive.",
    "The flight app's customer service is a joke. No one seems to know how to resolve issues promptly.",
    "Hotel confirmation emails never arrive. I had to call the hotel directly to ensure my reservation was valid.",
    "Flight app fails to provide accurate arrival times. Missed an important meeting due to this inaccuracy.",
    "The hotel app's recommended properties are subpar. Ended up in a rundown place despite the app's endorsement.",
    "Flight booking process is slow and clunky. It feels like I'm stuck in the early 2000s with this app.",
    "Hotel app's payment system is insecure. Concerned about the safety of my credit card information.",
    "Flight app's interface is not intuitive. Difficult to navigate and find the information I need quickly.",
    "Hotel reservations mysteriously disappear from the app. I only realized my booking was gone when I arrived at the hotel.",
    "Flight app constantly logs me out, making it frustrating to access my booking details when needed.",
    "Hotel app lacks customer support. No one responded when I had an issue with my reservation.",
    "Flight prices skyrocket during peak hours. Feels like I'm being taken advantage of as a traveler.",
    "The hotel app's map feature is inaccurate. Ended up in the wrong neighborhood due to this misdirection.",
    "Flight app's notifications are inconsistent. Sometimes I receive them, other times I don't, leading to missed updates."

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

df
# Out:
#                                                Review
# 0             The app is slow and crashes frequently.
# 1                 Great app, but needs more features.
# 2     Terrible user interface, difficult to navigate.
# 3   Love the design, but it lacks important functi...
# 4                    Constantly freezes on my device.
# 5       Excellent features, but the ads are annoying.
# 6   Navigation is smooth, but the content is outda...
# 7   Crashed during an important task, very frustra...
# 8   Intuitive interface, but the performance is poor.
# 9   Ads pop up too often, disrupts the learning ex...
# 10  Impressive functionality, but it drains my bat...
# 11      Difficult to find specific topics in the app.
# 12  Smooth experience overall, but the login proce...
# 13               Too many bugs, needs a major update.
# 14               The app is not user-friendly at all.
# 15       Informative content, but the UI is outdated.
# ...

# %%
import nltk

# Tokenization and Vectorization
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
vectorizer = TfidfVectorizer(stop_words=stop_words)
X = vectorizer.fit_transform(df['Review'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-6-1142351f9baa> in <cell line: 7>()
#       5 stop_words = set(stopwords.words('english'))
#       6 vectorizer = TfidfVectorizer(stop_words=stop_words)
# ----> 7 X = vectorizer.fit_transform(df['Review'])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2131             sublinear_tf=self.sublinear_tf,
#    2132         )
# -> 2133         X = super().fit_transform(raw_documents)
#    2134         self._tfidf.fit(X)
#    2135         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
# ...
